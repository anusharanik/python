# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\python\pyenv\lib\site-packages (3.9.2)
# Requirement already satisfied: click in d:\python\pyenv\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in d:\python\pyenv\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\python\pyenv\lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in d:\python\pyenv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\python\pyenv\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
corpus="""Hello Welcome to my tutorial.
You can find everything on my git account! to become an expert in AI."""

# %%
print(corpus)
# Out:
# Hello Welcome to my tutorial.
# You can find everything on my git account! to become an expert in AI.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ishaan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
##Tokenization
#Paragraph -->sentence
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome to my tutorial.
# You can find everything on my git account!
# to become an expert in AI.

# %%
##Tokenization
##Paragraph-->words
##Sentence-->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'my',
#  'tutorial',
#  '.',
#  'You',
#  'can',
#  'find',
#  'everything',
#  'on',
#  'my',
#  'git',
#  'account',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'AI',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', 'to', 'my', 'tutorial', '.']
# ['You', 'can', 'find', 'everything', 'on', 'my', 'git', 'account', '!']
# ['to', 'become', 'an', 'expert', 'in', 'AI', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'my',
#  'tutorial',
#  '.',
#  'You',
#  'can',
#  'find',
#  'everything',
#  'on',
#  'my',
#  'git',
#  'account',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert',
#  'in',
#  'AI',
#  '.']

# %%
from nltk.tokenize import TreebankWordDetokenizer

# %%
tokenizer=TreebankWordDetokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# 'H e l l o   W e l c o m e   t o   m y   t u t o r i a l . \n Y o u   c a n   f i n d   e v e r y t h i n g   o n   m y   g i t   a c c o u n t!   t o   b e c o m e   a n   e x p e r t   i n   A I.'
