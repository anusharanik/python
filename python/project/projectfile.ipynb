# %%
pip install youtube_transcript_api
# Out:
# Requirement already satisfied: youtube_transcript_api in d:\python\pyenv\lib\site-packages (1.2.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in d:\python\pyenv\lib\site-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in d:\python\pyenv\lib\site-packages (from youtube_transcript_api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\python\pyenv\lib\site-packages (from requests->youtube_transcript_api) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\python\pyenv\lib\site-packages (from requests->youtube_transcript_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python\pyenv\lib\site-packages (from requests->youtube_transcript_api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python\pyenv\lib\site-packages (from requests->youtube_transcript_api) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
def get_video_id(url_link):
    return url_link.split("watch?v=")[-1]

# %%
video_id=get_video_id("https://www.youtube.com/watch?v=xDQL3vWwcp0")
print(video_id)
# Out:
# xDQL3vWwcp0

# %%
transcript = YouTubeTranscriptApi.get_transcript('xDQL3vWwcp0')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 transcript = YouTubeTranscriptApi.get_transcript('xDQL3vWwcp0')
#
# AttributeError: type object 'YouTubeTranscriptApi' has no attribute 'get_transcript'
